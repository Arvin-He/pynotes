# %% [markdown]
# # pymysql使用

# %%
import pymysql

def list_all_databases():
    db = pymysql.connect(host='192.168.118.150', port=3306, user='CloudOptimus_Dev', passwd='Gx56/#df26', db='CloudOptimus_Dev', charset="utf8")
    cursor = db.cursor()
    cursor.execute("show databases")
    db_list = [item[0] for item in cursor.fetchall()]
    print(db_list)
#     for item in cursor.fetchall():
#         print(item)
    db.close()
    
list_all_databases()
# Out:
# ['information_schema', 'CloudOptimus_Dev']

# %%
import pymysql

def create_databases():
    db = pymysql.connect(host='127.0.0.1', port=3306, user='root', passwd='123456', db='CloudOptimus', charset="utf8")
    cursor = db.cursor()
    cursor.execute("use CloudOptimus")
    db_list = [item[0] for item in cursor.fetchall()]
    print(db_list)
#     for item in cursor.fetchall():
#         print(item)
    db.close()
    
create_databases()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-14-4040ffc16a4f> in <module>()
#      11     db.close()
#      12
# ---> 13 create_databases()
#
# <ipython-input-14-4040ffc16a4f> in create_databases()
#       2
#       3 def create_databases():
# ----> 4     db = pymysql.connect(host='127.0.0.1', port=3306, user='root', passwd='123456', db='CloudOptimus', charset="utf8")
#       5     cursor = db.cursor()
#       6     cursor.execute("use CloudOptimus")
#
# c:\program files\python36\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# ...

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker  
from sqlalchemy import Column
from sqlalchemy.types import CHAR, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from random import randint
from sqlalchemy import ForeignKey

DB_CONNECT = 'mysql+mysqldb://root:123456@localhost/mydb'
engine = create_engine(DB_CONNECT, echo=True)
DB_Session = sessionmaker(bind=engine)
session = DB_Session()

BaseModel = declarative_base()



def init_db():
    BaseModel.metadata.create_all(engine)

def drop_db():
    BaseModel.metadata.drop_all()

    
init_db()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\program files\python36\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# c:\program files\python36\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# c:\program files\python36\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# c:\program files\python36\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ...

# %%
import pymysql

def create_databases():
    # 数据库连接
    db = pymysql.connect(host='127.0.0.1', port=3306, user='root', passwd='123456', db='CloudOptimus', charset="utf8")
    # 创建游标，通过连接与数据通信
    cursor = db.cursor()
    # 执行sql语句
    cursor.execute('show databases')
    rows = cursor.fetchall()
    for row in rows:
        tmp = "%2s" % row
    # 判断数据库是否存在
        if name == tmp:
        cursor.execute('drop database if exists ' + name)
        cursor.execute('create database if not exists ' + name)
    # 提交到数据库执行
    db.commit()
    db.close()

# %%
import pymysql
import sys
# python mysql 创建库、表增删改查标准语句
print('----------------------------')
print('载入mysql模块完成')

con = pymysql.connect(host='localhost', user='root',
                      passwd='123456', charset='utf8')

# con = pymysql.connect(host='localhost', user='root', passwd='123456', db='test_db',  charset='utf8') # 直接连入db1库

print('创建连接完成')
cur = con.cursor()
print('获取光标完成')

cur.execute("create database test_db character set utf8;")
print('创建test_db库完成')

cur.execute("use test_db;")
print('进入test_db库完成')

cur.execute("create table test_tab(id int,name char(20))character set utf8;")
print('创建test_tab表完成')

count = 0
while True:
    sql_insert = 'insert into test_tab(id,name) values(%s,%s);'
    ID = input('请输入id：')
    if not ID:
        break
    name = input('请输入名字：')
    try:
        cur.execute(sql_insert, [int(ID), name])
        count += 1
        con.commit()
        print('添加第%d条记录' % count, int(ID), name)
    except Exception as e:
        print('出错回滚完成', e)
        con.rollback()
        cur.close()
        con.close()
        sys.exit()
del count
print('sql写入语句执行完成')
sql_select = 'select * from test_tab;'
sql_delete = 'delete from test_tab where id=4;'
sql_update = 'update table set name ="大胖" where id=3;'
print('创建sql语句完成')
try:
    cur.execute(sql_select)
    print('sql查询语句执行完成')
    data_one = cur.fetchone()
    print(data_one)
    print('已显示第一条记录')
    data_many = cur.fetchmany(2)
    print(data_many)
    print('已显示后面两条记录')
    data_all = cur.fetchall()
    print(data_all)
    print('已显示后面全部记录')
    cur.execute(sql_delete)
    print('sql删除语句执行完成')
    cur.execute(sql_update)
    print('sql更新语句执行完成')
    con.commit()
    print('sql写入完成')
except Exception as e:
    print('出错回滚完成', e)
    con.rollback()
cur.close()
print('关闭光标完成')
con.close()
print('关闭连接完成')
print('程序结束')
print('----------------------------')
