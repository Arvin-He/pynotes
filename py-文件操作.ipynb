# %% [markdown]
# # py-文件操作

# %%
# 文件读写
# 文件mode: w r a b w+ r+ a+ wb rb ab
with open("file_path.txt", "r", encoding="utf-8") as f:
    for line in f:
        print(line)

with open("file_path.txt", "w", encoding="utf-8") as f:
    f.write("{}\n".format("line"))


# 读写json文件
import json

# 加载json配置文件
def loadJson(config_path):
    try:
        with open(config_path, 'r', encoding='utf-8') as f:
            return json.load(f)
    except Exception as e:
        log.error("json文件加载出错:{}".format(e))


# 写配置文件
def dumpJson(config_path, data):
    try:
        with open(config_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
    except Exception as e:
        log.error("json文件写入出错:{}".format(e))

        
# 读写ini文件



# 文件压缩
import sys
import subprocess
from random import choice


def genPasswd(length=8, chars=string.ascii_letters + string.digits):
    log.info("生成压缩文件密码...")
    return ''.join([choice(chars) for i in range(length)])


def tarData(srcPath, dstname, passwd):
    log.info("开始打包压缩数据,请耐心等待...")
    log.info("压缩包密码:{}".format(passwd))
    try:
        src_path = "{}/".format(os.path.basename(srcPath))
        log.info("使用zip格式压缩!")
        tar_zip(srcPath, dstname, passwd)
    except Exception as e:
        log.error("压缩文件出错:{}".format(e))
    log.info("打包压缩数据完成!")


# 压缩文件夹尾
def tar_zip(srcPath, dstname, passwd, formatter="zip"):
    start = time.time()
    if formatter == "zip":
        if sys.platform == "win32":
            subprocess.check_call(
                ["7z", "a", "-tzip", dstname, srcPath, "-p{}".format(passwd)])
        else:
            subprocess.check_call(["zip", "-rP", passwd, dstname, srcPath])
    elif formatter == "7z":
        subprocess.check_call(
            ["7z", "a",  dstname + ".7z", srcPath, "-p{}".format(passwd)])
    log.info("压缩时间:{:.1f}秒.".format(time.time() - start))
